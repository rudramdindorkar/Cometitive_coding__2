# %%
math=40
pi = 3.14
name ='Rd'
print(type(math))
print(type(pi))
print(type(name))
# Out:
# Running cells with 'Python 3.13.2' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3.13 -m pip install ipykernel -U --user --force-reinstall'

# %%
#type casting
print(2+2)
print("2"+"2")
val = int(input("enter"))
val2 = int(input("enter"))
print(val+val2)

# %%
print(int(3.14))
print(int(True))
print(int(False))
print(int("4"))

# %%
print(float(3.14))
print(float(True))
print(float(False))
print(float("4.22"))

# %%
print(complex(2))
print(complex(True))
print(complex(False))

# %%
print(bool(True))
print(bool(35))
print(bool(0))

# %%
#wap for simple interst
#p
p =10000
roi = 10
time =1
SI = p * roi * time/100
print("SI==",SI)

# %%
#wap for centrigrade temp to franhinte
#f=9/5*C+32
T_c=32
T_F=(9/5 * T_c)+32
print(T_F)

# %%
v1=21
v2=12
temp =v1
v1 = v2
v2 = temp
print(v1)
print(v2)

# %%
a=12
b=21
a= a+b
b= a-b
a=a-b
print("a==",a)
print("b==",b)

# %%
h_feet=12
h_innch=h_feet*22
h_cm =h_innch*2.24
print(h_innch)
print(h_cm)

# %%
num=123
a=num %10
num = num // 10
print(a)
b=num%10
print(b)
c=num % 10
num = num // 10
rev = a*100+b*10+c*1
print(rev)
